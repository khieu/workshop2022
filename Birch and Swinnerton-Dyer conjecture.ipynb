# %% [markdown]
# ## Applying Regression techniques to Birch and Swinnerton-Dyer conjecture
# We have the following conjecture about elipptic curves: $special\_value \cdot torsion^2 = sha \cdot real\_period \cdot regulator \cdot tamagawa\_product$
#
# can we use regression techniques in computer science to model this problem?
#
# - Verification with Linear Regression
# - discovering new relations with Polynomial Regression
#
# To prepare for this notebook, download the BSD dataset at https://math.mit.edu/~drew/mldata/bsd.txt and put it to the same director as this notebook

# %% [markdown]
# ### Verifying the relations with Linear Regression

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import time
from sklearn.model_selection import train_test_split
import math

# %%
with open('./bsd.txt') as f:
    data = [l for l in f.readlines()]
data = [item.split(':') for item in data]

# %% [markdown]
# ##### Spliting data to inputs (sha, real period, regulator and tamagawa product) and outputs (special value * torsion ^2)
#
# - To apply linear regression, we need to take the Log of both side of the equation, so we have:
#     - $\log(special\_value \cdot torsion^2) = \log(sha) + \log(real\_period) + \log(regulator) + \log(tamagawa\_product)$

# %%
targets = []
inputs = []
log_targets = []
log_inputs = []
for point in data:
    special_value, torsion = float(point[1]), int(point[2])
    sha, real_period, regulator, tagamawa_product = int(point[3]), float(point[4]), float(point[5]), int(point[6])
    output = special_value * (torsion**2)
    targets.append(output)
    inputs.append([sha, real_period, regulator, tagamawa_product]) 
    
    log_output = math.log(output)
    #log_targets.append(log_output)
    #log_inputs.append([math.log(sha), math.log(real_period), math.log(regulator), math.log(tagamawa_product)])
    log_targets.append(math.log(special_value))
    log_inputs.append([math.log(sha), math.log(real_period), math.log(regulator), math.log(tagamawa_product),\
                      math.log(torsion)])

# %%
X_train, X_test, y_train, y_test = train_test_split(log_inputs, log_targets, test_size=0.3)

# %%
model = LinearRegression()

# %%
start = time.time_ns()/1000000
model.fit(X_train,y_train)
end = time.time_ns()/1000000
print('Linear regression takes ', str(end-start), 'milliseconds')
# Out:
# Linear regression takes  6307.384765625 milliseconds

# %%
y_pred = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# -2.584221725498992e-11
# [ 1.  1.  1.  1. -2.]

# %% [markdown]
# the intercept is almost $0$ or negligible, and all the coefficient of the inputs are $1$, thus confirm the speculation through these examples.

# %%
#  Showing the model prediction: true output ~ predicted_output =log(sha) + log(real_period) + log(regulator) + log(tamagawa_product)
test_input = log_inputs[100]
test_output = log_targets[100]
print(model.intercept_ + np.dot(model.coef_, test_input), test_output)
# Out:
# 1.8799073531471011 1.8799073531729453

# %% [markdown]
# #### Showcasing the predicted results

# %%
import pandas as pd
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#            Actual  Predicted
# 0        2.263811   2.263811
# 1        1.363612   1.363612
# 2        2.451857   2.451857
# 3        0.805661   0.805661
# 4        1.937410   1.937410
# 5        2.116595   2.116595
# 6       -1.924923  -1.924923
# 7       -1.218729  -1.218729
# 8        1.609706   1.609706
# 9        2.587444   2.587444
# 10       3.249580   3.249580
# 11       1.574080   1.574080
# 12       1.775314   1.775314
# 13      -0.265889  -0.265889
# 14       1.774981   1.774981
# 15       2.446681   2.446681
# 16      -0.507799  -0.507799
# 17       0.436574   0.436574
# 18       2.934562   2.934562
# 19       2.930611   2.930611
# 20       0.949910   0.949910
# 21       2.327283   2.327283
# 22       1.086373   1.086373
# 23       2.042469   2.042469
# 24       1.755037   1.755037
# 25       0.067483   0.067483
# 26       0.987484   0.987484
# 27       1.633473   1.633473
# 28       2.574181   2.574181
# 29       1.811740   1.811740
# ...           ...        ...
# 1147282 -0.542948  -0.542948
# 1147283  0.873529   0.873529
# 1147284  0.051070   0.051070
# 1147285  3.084390   3.084390
# 1147286  1.532201   1.532201
# 1147287  2.205338   2.205338
# 1147288 -0.494694  -0.494694
# 1147289  2.590255   2.590255
# 1147290  2.045291   2.045291
# 1147291  0.405139   0.405139
# 1147292  2.408183   2.408183
# 1147293  1.223137   1.223137
# 1147294  3.267632   3.267632
# 1147295  2.442012   2.442012
# 1147296  3.062853   3.062853
# 1147297  2.030366   2.030366
# 1147298  1.597400   1.597400
# 1147299  2.526952   2.526952
# 1147300  1.898318   1.898318
# 1147301  2.193679   2.193679
# 1147302  1.189587   1.189587
# 1147303  1.525071   1.525071
# 1147304  1.938316   1.938316
# 1147305  1.083449   1.083449
# 1147306  1.100520   1.100520
# 1147307  1.942161   1.942161
# 1147308  2.344858   2.344858
# 1147309  2.546733   2.546733
# 1147310  0.775289   0.775289
# 1147311  0.537871   0.537871
#
# [1147312 rows x 2 columns]

# %% [markdown]
# ### Approximate BSD with Polynomial Regression
#
# we can also approximate $special\_value \cdot torsion^2$ with the 4 input values using the polynomial Regression techniques.
# In this example, we operate directly on the input values, not the $\ln$ of the inputs

# %%
X_train_orig, X_test_orig, y_train_orig, y_test_orig = train_test_split(inputs, targets, test_size=0.3)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures

degree=3
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train_orig,y_train_orig)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=3)),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_poly = polyreg.predict(X_test_orig)
y_train_pred_poly = polyreg.predict(X_train_orig)

# %%
df = pd.DataFrame({'Actual': y_train_orig, 'Predicted': y_train_pred_poly})
df
# Out:
#             Actual  Predicted
# 0         3.226683   3.240413
# 1        89.254600  89.213342
# 2        11.894917  11.870497
# 3         4.185799   4.297215
# 4        19.763617  19.750329
# 5         5.282492   5.282106
# 6        38.637670  38.621750
# 7         2.556541   2.587699
# 8         8.981322   9.014454
# 9        68.089808  69.534225
# 10        6.485740   6.518096
# 11        5.210593   5.291384
# 12        7.056667   7.144059
# 13        5.968128   6.065608
# 14        8.329041   8.317057
# 15       36.626583  36.679384
# 16       20.698084  20.751804
# 17        6.956503   7.047122
# 18        5.214256   5.293641
# 19        6.470516   6.462494
# 20        5.488930   5.571558
# 21        7.954243   8.005335
# 22       75.873438  76.002131
# 23        4.839417   4.844799
# 24       13.924141  14.027523
# 25        3.459007   3.575547
# 26        4.386919   4.384767
# 27       19.975294  20.076584
# 28        4.316255   4.377231
# 29        2.780217   2.825569
# ...            ...        ...
# 2677030   4.677474   4.700703
# 2677031  10.971077  10.955296
# 2677032  40.021349  40.030073
# 2677033   2.935466   2.987884
# 2677034   7.409248   7.461790
# 2677035   3.416161   3.397898
# 2677036  35.565881  35.631083
# 2677037  30.238938  30.252292
# 2677038   9.996288  10.047837
# 2677039  14.573084  14.635104
# 2677040  11.298406  11.302334
# 2677041  16.657532  16.750052
# 2677042   5.388136   5.589760
# 2677043   5.737618   5.711286
# 2677044  19.970533  19.948258
# 2677045   4.205346   4.267826
# 2677046   5.557546   5.639643
# 2677047  11.150757  11.138533
# 2677048  10.930294  11.010087
# 2677049  37.454791  37.476727
# 2677050  28.517478  29.171851
# 2677051  39.982682  39.997512
# 2677052  37.595926  37.717694
# 2677053  11.398647  11.403234
# 2677054   2.390901   2.506693
# 2677055   3.904706   3.931643
# 2677056  10.837398  10.813872
# 2677057   8.394837   8.475412
# 2677058   0.934988   0.910430
# 2677059   9.445528   9.476857
#
# [2677060 rows x 2 columns]

# %%
polyreg = LinearRegression()
polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(X_train_orig)

# %%
model.fit(x_poly, y_train_orig)
y_poly_pred = model.predict(x_poly)

# %%
df = pd.DataFrame({'Actual': y_train_orig, 'Predicted': y_poly_pred})
df
# Out:
#             Actual  Predicted
# 0         3.226683   3.240413
# 1        89.254600  89.213342
# 2        11.894917  11.870497
# 3         4.185799   4.297215
# 4        19.763617  19.750329
# 5         5.282492   5.282106
# 6        38.637670  38.621750
# 7         2.556541   2.587699
# 8         8.981322   9.014454
# 9        68.089808  69.534225
# 10        6.485740   6.518096
# 11        5.210593   5.291384
# 12        7.056667   7.144059
# 13        5.968128   6.065608
# 14        8.329041   8.317057
# 15       36.626583  36.679384
# 16       20.698084  20.751804
# 17        6.956503   7.047122
# 18        5.214256   5.293641
# 19        6.470516   6.462494
# 20        5.488930   5.571558
# 21        7.954243   8.005335
# 22       75.873438  76.002131
# 23        4.839417   4.844799
# 24       13.924141  14.027523
# 25        3.459007   3.575547
# 26        4.386919   4.384767
# 27       19.975294  20.076584
# 28        4.316255   4.377231
# 29        2.780217   2.825569
# ...            ...        ...
# 2677030   4.677474   4.700703
# 2677031  10.971077  10.955296
# 2677032  40.021349  40.030073
# 2677033   2.935466   2.987884
# 2677034   7.409248   7.461790
# 2677035   3.416161   3.397898
# 2677036  35.565881  35.631083
# 2677037  30.238938  30.252292
# 2677038   9.996288  10.047837
# 2677039  14.573084  14.635104
# 2677040  11.298406  11.302334
# 2677041  16.657532  16.750052
# 2677042   5.388136   5.589760
# 2677043   5.737618   5.711286
# 2677044  19.970533  19.948258
# 2677045   4.205346   4.267826
# 2677046   5.557546   5.639643
# 2677047  11.150757  11.138533
# 2677048  10.930294  11.010087
# 2677049  37.454791  37.476727
# 2677050  28.517478  29.171851
# 2677051  39.982682  39.997512
# 2677052  37.595926  37.717694
# 2677053  11.398647  11.403234
# 2677054   2.390901   2.506693
# 2677055   3.904706   3.931643
# 2677056  10.837398  10.813872
# 2677057   8.394837   8.475412
# 2677058   0.934988   0.910430
# 2677059   9.445528   9.476857
#
# [2677060 rows x 2 columns]

# %%
x_poly[0,:].shape
# Out:
# (35,)

# %%
np.dot(model.coef_, x_poly[0,:]) + model.intercept_
# Out:
# 3.2404128911177144

# %% [markdown]
# ##### Output of Polynomial Regression
#
# from the above output, PolynomialFeatures predicted some polynomial coefficients for all polynomial combinations of the features with degree less than or equal to the specified degree (in this case 3rd degree). In other words, for 4 variables, we have a polynomial consists of : $1, a, b,c,d, a^2, ab, ac , ad, b^2 \cdots a^3, a^2b, \cdots a^4 \cdots$. There are:
# - $C(6, 3)$ terms for $(a+b+c+d)^4$
# - $C(5,2)$ terms for $(a+b+c+d)^3$
# - $C(4,1)$ terms for $(a+b+c+d)^2$
# - $C(3, 0)$ terms for $(a+b+c+d)^1$
# - thus we have a polynomial with 35 terms
